# %% [markdown]
# # Creating Raw Nexus File

# %%
import numpy as np
import h5py
from lxml import etree

# ------------------------------------------------------------------------------
# 1) CONFIGURATION
# ------------------------------------------------------------------------------
nxdl_file_path = "NXem.nxdl.xml"       # Path to your NXem definition XML
output_nexus_file = "NXem_regenerated.nxs"   # Output file name

# XML namespace for NXDL
NS = {'nx': 'http://definition.nexusformat.org/nxdl/3.1'}

# ------------------------------------------------------------------------------
# 2) PARSE THE NXDL FILE
# ------------------------------------------------------------------------------
tree = etree.parse(nxdl_file_path)
root = tree.getroot()

# ------------------------------------------------------------------------------
# 3) RECURSIVELY EXTRACT THE NXDL STRUCTURE
# ------------------------------------------------------------------------------
def extract_full_structure(parent_element):
    """
    Recursively find <group> or <field> tags in the NXDL and build a nested
    Python list/dict structure describing them.
    """
    structure = []
    for element in parent_element:
        # Skip comments and processing instructions:
        if not isinstance(element.tag, str):
            continue

        tag_name = etree.QName(element.tag).localname

        if tag_name in ["group", "field"]:
            # For groups, 'name' might be set or 'type' might be used as fallback
            # For fields, 'name' is definitely present (type can indicate NX_CHAR, etc.)
            structure.append({
                "tag": tag_name,
                "name": element.get("name") or element.get("type"),
                "type": element.get("type"),
                "children": extract_full_structure(element)  # recursion
            })
    return structure

# ------------------------------------------------------------------------------
# 4) GENERATE A DEFAULT VALUE FOR FIELDS BASED ON TYPE
# ------------------------------------------------------------------------------
def get_default_value(nx_type):
    """
    Return a simple placeholder data value for each field, based on the NXDL type.
    """
    if nx_type:
        lower = nx_type.lower()
        if "int" in lower:
            return 0
        elif "float" in lower or "double" in lower:
            return 0.0
        elif "char" in lower or "string" in lower:
            # By default, let's just say "unset"
            return np.bytes_("unset")
    # Fallback string
    return np.bytes_("unset")

# ------------------------------------------------------------------------------
# 5) FUNCTION TO WRITE HDF5
# ------------------------------------------------------------------------------
def create_nexus_file(filename, structure):
    """
    Creates an HDF5 file from a list of (group or field) dictionaries.
    """
    def add_elements(h5group, elements):
        for el in elements:
            if not el.get("tag") or not el.get("name"):
                continue

            tag = el["tag"]
            name = el["name"]
            nx_type = el["type"]
            children = el.get("children", [])

            if tag == "group":
                # Create subgroup
                subgroup = h5group.create_group(name)
                # If "type" is e.g. NXentry, store it in the NX_class attribute
                if nx_type:
                    subgroup.attrs["NX_class"] = nx_type
                # Recursively add child elements
                add_elements(subgroup, children)

            elif tag == "field":
                # Create a dataset. If we have an explicit "value" key, use that.
                # Otherwise generate a default placeholder from the type.
                if "value" in el:
                    dataset_value = np.bytes_(el["value"])
                else:
                    dataset_value = get_default_value(nx_type)

                try:
                    if name not in h5group:
                        h5group.create_dataset(name, data=dataset_value)
                    else:
                        print(f"⚠️ Skipping existing dataset '{name}'")
                except Exception as exc:
                    print(f"⚠️ Could not create dataset '{name}': {exc}")

    with h5py.File(filename, "w") as f:
        add_elements(f, structure)

# ------------------------------------------------------------------------------
# 6) FIND THE TOP-LEVEL GROUP THAT EXTENDS "NXentry"
# ------------------------------------------------------------------------------
entry_groups = root.findall(".//nx:group[@type='NXentry']", namespaces=NS)
if not entry_groups:
    raise ValueError("❌ No <group type='NXentry'> found in NXDL XML!")

# Extract the structure under this NXentry block
entry_structure = extract_full_structure(entry_groups[0])

# ------------------------------------------------------------------------------
# 7) MANUALLY INSERT A 'definition' FIELD = "NXem"
# ------------------------------------------------------------------------------
# By explicitly setting "value": "NXem" here, we ensure the dataset is exactly "NXem".
# That prevents NOMAD from searching for "NXem.nxdl.xml.nxdl.xml" or similar.
entry_structure.insert(0, {
    "tag": "field",
    "name": "definition",
    "type": "NX_CHAR",
    "value": "NXem"   # <--- crucial so that NOMAD sees the definition as "NXem"
})

# ------------------------------------------------------------------------------
# 8) WRAP THIS ENTRY STRUCTURE IN A TOP-LEVEL GROUP NAMED "/entry" with NX_class = NXentry
# ------------------------------------------------------------------------------
wrapped_structure = [{
    "tag": "group",
    "name": "entry",
    "type": "NXentry",
    "children": entry_structure
}]

# ------------------------------------------------------------------------------
# 9) WRITE THE NeXus FILE
# ------------------------------------------------------------------------------
create_nexus_file(output_nexus_file, wrapped_structure)
print(f"✅ NeXus file created: {output_nexus_file}")
# Out:
# ⚠️ Skipping existing dataset 'definition'
# ✅ NeXus file created: NXem_regenerated.nxs

# %%
import h5py

with h5py.File("NXem_regenerated.nxs", "r") as f:
    f.visit(lambda name: print(name))
# Out:
# entry
# entry/NXcoordinate_system_set
# entry/NXcoordinate_system_set/TRANSFORMATIONS
# entry/NXdata
# entry/NXmonitor
# entry/NXprogram
# entry/NXprogram/program
# entry/NXuser
# entry/NXuser/address
# entry/NXuser/affiliation
# entry/NXuser/email
# entry/NXuser/name
# entry/NXuser/orcid
# entry/NXuser/orcid_platform
# entry/NXuser/role
# entry/NXuser/social_media_name
# entry/NXuser/social_media_platform
# entry/NXuser/telephone_number
# entry/definition
# entry/em_lab
# entry/em_lab/DETECTOR
# entry/em_lab/DETECTOR/NXfabrication
# entry/em_lab/DETECTOR/NXfabrication/identifier
# entry/em_lab/DETECTOR/local_name
# entry/em_lab/EBEAM_DEFLECTOR
# entry/em_lab/EBEAM_DEFLECTOR/NXfabrication
# entry/em_lab/EBEAM_DEFLECTOR/NXfabrication/identifier
# entry/em_lab/EBEAM_DEFLECTOR/NXfabrication/model
# entry/em_lab/EBEAM_DEFLECTOR/NXfabrication/vendor
# entry/em_lab/EBEAM_DEFLECTOR/pixel_time
# entry/em_lab/IBEAM_DEFLECTOR
# entry/em_lab/IBEAM_DEFLECTOR/NXfabrication
# entry/em_lab/IBEAM_DEFLECTOR/NXfabrication/identifier
# entry/em_lab/IBEAM_DEFLECTOR/NXfabrication/model
# entry/em_lab/IBEAM_DEFLECTOR/NXfabrication/vendor
# entry/em_lab/NXchamber
# entry/em_lab/NXebeam_column
# entry/em_lab/NXebeam_column/NXaperture_em
# entry/em_lab/NXebeam_column/NXaperture_em/NXfabrication
# entry/em_lab/NXebeam_column/NXaperture_em/NXfabrication/identifier
# entry/em_lab/NXebeam_column/NXaperture_em/NXfabrication/model
# entry/em_lab/NXebeam_column/NXaperture_em/NXfabrication/vendor
# entry/em_lab/NXebeam_column/NXaperture_em/description
# entry/em_lab/NXebeam_column/NXaperture_em/name
# entry/em_lab/NXebeam_column/NXaperture_em/value
# entry/em_lab/NXebeam_column/NXchamber
# entry/em_lab/NXebeam_column/NXfabrication
# entry/em_lab/NXebeam_column/NXfabrication/identifier
# entry/em_lab/NXebeam_column/NXfabrication/model
# entry/em_lab/NXebeam_column/NXfabrication/vendor
# entry/em_lab/NXebeam_column/NXlens_em
# entry/em_lab/NXebeam_column/NXlens_em/NXfabrication
# entry/em_lab/NXebeam_column/NXlens_em/NXfabrication/identifier
# entry/em_lab/NXebeam_column/NXlens_em/NXfabrication/model
# entry/em_lab/NXebeam_column/NXlens_em/NXfabrication/vendor
# entry/em_lab/NXebeam_column/NXlens_em/current
# entry/em_lab/NXebeam_column/NXlens_em/value
# entry/em_lab/NXebeam_column/NXlens_em/voltage
# entry/em_lab/NXebeam_column/aberration_correction
# entry/em_lab/NXebeam_column/aberration_correction/NXfabrication
# entry/em_lab/NXebeam_column/aberration_correction/NXfabrication/identifier
# entry/em_lab/NXebeam_column/aberration_correction/NXfabrication/model
# entry/em_lab/NXebeam_column/aberration_correction/NXfabrication/vendor
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/angle
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/delta_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/magnitude
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/uncertainty
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/uncertainty_model
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/description
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/exposure_time
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/magnification
# entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/tilt_angle
# entry/em_lab/NXebeam_column/aberration_correction/applied
# entry/em_lab/NXebeam_column/aberration_correction/name
# entry/em_lab/NXebeam_column/electron_source
# entry/em_lab/NXebeam_column/electron_source/NXfabrication
# entry/em_lab/NXebeam_column/electron_source/NXfabrication/identifier
# entry/em_lab/NXebeam_column/electron_source/NXfabrication/model
# entry/em_lab/NXebeam_column/electron_source/NXfabrication/vendor
# entry/em_lab/NXebeam_column/electron_source/emitter_type
# entry/em_lab/NXebeam_column/electron_source/name
# entry/em_lab/NXebeam_column/electron_source/voltage
# entry/em_lab/NXfabrication
# entry/em_lab/NXfabrication/capabilities
# entry/em_lab/NXfabrication/identifier
# entry/em_lab/NXfabrication/model
# entry/em_lab/NXfabrication/vendor
# entry/em_lab/NXibeam_column
# entry/em_lab/NXibeam_column/NXaperture_em
# entry/em_lab/NXibeam_column/NXaperture_em/NXfabrication
# entry/em_lab/NXibeam_column/NXaperture_em/NXfabrication/identifier
# entry/em_lab/NXibeam_column/NXaperture_em/NXfabrication/model
# entry/em_lab/NXibeam_column/NXaperture_em/NXfabrication/vendor
# entry/em_lab/NXibeam_column/NXaperture_em/value
# entry/em_lab/NXibeam_column/NXchamber
# entry/em_lab/NXibeam_column/NXfabrication
# entry/em_lab/NXibeam_column/NXfabrication/identifier
# entry/em_lab/NXibeam_column/NXfabrication/model
# entry/em_lab/NXibeam_column/NXfabrication/vendor
# entry/em_lab/NXibeam_column/NXlens_em
# entry/em_lab/NXibeam_column/NXlens_em/NXfabrication
# entry/em_lab/NXibeam_column/NXlens_em/NXfabrication/identifier
# entry/em_lab/NXibeam_column/NXlens_em/current
# entry/em_lab/NXibeam_column/NXlens_em/value
# entry/em_lab/NXibeam_column/NXlens_em/voltage
# entry/em_lab/NXibeam_column/ion_source
# entry/em_lab/NXibeam_column/ion_source/NXfabrication
# entry/em_lab/NXibeam_column/ion_source/NXfabrication/identifier
# entry/em_lab/NXibeam_column/ion_source/NXfabrication/model
# entry/em_lab/NXibeam_column/ion_source/NXfabrication/vendor
# entry/em_lab/NXibeam_column/ion_source/current
# entry/em_lab/NXibeam_column/ion_source/emitter_type
# entry/em_lab/NXibeam_column/ion_source/name
# entry/em_lab/NXibeam_column/ion_source/probe
# entry/em_lab/NXibeam_column/ion_source/probe/charge_state
# entry/em_lab/NXibeam_column/ion_source/probe/isotope_vector
# entry/em_lab/NXibeam_column/ion_source/probe/name
# entry/em_lab/NXibeam_column/ion_source/voltage
# entry/em_lab/NXoptical_system_em
# entry/em_lab/NXoptical_system_em/beam_current
# entry/em_lab/NXoptical_system_em/beam_current_description
# entry/em_lab/NXoptical_system_em/camera_length
# entry/em_lab/NXoptical_system_em/defocus
# entry/em_lab/NXoptical_system_em/magnification
# entry/em_lab/NXoptical_system_em/semi_convergence_angle
# entry/em_lab/NXoptical_system_em/working_distance
# entry/em_lab/NXpump
# entry/em_lab/instrument_name
# entry/em_lab/location
# entry/em_lab/stage_lab
# entry/em_lab/stage_lab/NXfabrication
# entry/em_lab/stage_lab/NXfabrication/capabilities
# entry/em_lab/stage_lab/NXfabrication/identifier
# entry/em_lab/stage_lab/NXfabrication/model
# entry/em_lab/stage_lab/NXfabrication/vendor
# entry/em_lab/stage_lab/description
# entry/em_lab/stage_lab/design
# entry/em_lab/stage_lab/name
# entry/em_lab/stage_lab/position
# entry/em_lab/stage_lab/rotation
# entry/em_lab/stage_lab/tilt_1
# entry/em_lab/stage_lab/tilt_2
# entry/end_time
# entry/experiment_description
# entry/experiment_documentation
# entry/experiment_identifier
# entry/measurement
# entry/measurement/NXevent_data_em
# entry/measurement/NXevent_data_em/IMAGE_SET
# entry/measurement/NXevent_data_em/IMAGE_SET/NXprocess
# entry/measurement/NXevent_data_em/IMAGE_SET/NXprocess/NXprogram
# entry/measurement/NXevent_data_em/IMAGE_SET/NXprocess/NXprogram/program
# entry/measurement/NXevent_data_em/IMAGE_SET/NXprocess/detector_identifier
# entry/measurement/NXevent_data_em/IMAGE_SET/NXprocess/mode
# entry/measurement/NXevent_data_em/IMAGE_SET/NXprocess/source
# entry/measurement/NXevent_data_em/IMAGE_SET/stack
# entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_image_identifier
# entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_x
# entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_y
# entry/measurement/NXevent_data_em/IMAGE_SET/stack/data_counts
# entry/measurement/NXevent_data_em/IMAGE_SET/stack/title
# entry/measurement/NXevent_data_em/NXuser
# entry/measurement/NXevent_data_em/NXuser/name
# entry/measurement/NXevent_data_em/SPECTRUM_SET
# entry/measurement/NXevent_data_em/SPECTRUM_SET/NXprocess
# entry/measurement/NXevent_data_em/SPECTRUM_SET/NXprocess/NXprogram
# entry/measurement/NXevent_data_em/SPECTRUM_SET/NXprocess/NXprogram/program
# entry/measurement/NXevent_data_em/SPECTRUM_SET/NXprocess/detector_identifier
# entry/measurement/NXevent_data_em/SPECTRUM_SET/NXprocess/mode
# entry/measurement/NXevent_data_em/SPECTRUM_SET/NXprocess/source
# entry/measurement/NXevent_data_em/SPECTRUM_SET/stack
# entry/measurement/NXevent_data_em/SPECTRUM_SET/stack/axis_energy
# entry/measurement/NXevent_data_em/SPECTRUM_SET/stack/axis_x
# entry/measurement/NXevent_data_em/SPECTRUM_SET/stack/axis_y
# entry/measurement/NXevent_data_em/SPECTRUM_SET/stack/data_counts
# entry/measurement/NXevent_data_em/SPECTRUM_SET/summary
# entry/measurement/NXevent_data_em/SPECTRUM_SET/summary/axis_energy
# entry/measurement/NXevent_data_em/SPECTRUM_SET/summary/data_counts
# entry/measurement/NXevent_data_em/adf
# entry/measurement/NXevent_data_em/adf/NXprocess
# entry/measurement/NXevent_data_em/adf/NXprocess/NXprogram
# entry/measurement/NXevent_data_em/adf/NXprocess/NXprogram/program
# entry/measurement/NXevent_data_em/adf/NXprocess/detector_identifier
# entry/measurement/NXevent_data_em/adf/NXprocess/mode
# entry/measurement/NXevent_data_em/adf/NXprocess/source
# entry/measurement/NXevent_data_em/adf/inner_half_angle
# entry/measurement/NXevent_data_em/adf/outer_half_angle
# entry/measurement/NXevent_data_em/adf/stack
# entry/measurement/NXevent_data_em/adf/stack/axis_image_identifier
# entry/measurement/NXevent_data_em/adf/stack/axis_x
# entry/measurement/NXevent_data_em/adf/stack/axis_y
# entry/measurement/NXevent_data_em/adf/stack/data_counts
# entry/measurement/NXevent_data_em/adf/stack/title
# entry/measurement/NXevent_data_em/eels
# entry/measurement/NXevent_data_em/eels/NXprocess
# entry/measurement/NXevent_data_em/eels/NXprocess/NXprogram
# entry/measurement/NXevent_data_em/eels/NXprocess/NXprogram/program
# entry/measurement/NXevent_data_em/eels/NXprocess/detector_identifier
# entry/measurement/NXevent_data_em/eels/NXprocess/mode
# entry/measurement/NXevent_data_em/eels/NXprocess/source
# entry/measurement/NXevent_data_em/eels/stack
# entry/measurement/NXevent_data_em/eels/stack/axis_energy_loss
# entry/measurement/NXevent_data_em/eels/stack/axis_x
# entry/measurement/NXevent_data_em/eels/stack/axis_y
# entry/measurement/NXevent_data_em/eels/stack/data_counts
# entry/measurement/NXevent_data_em/eels/stack/title
# entry/measurement/NXevent_data_em/eels/summary
# entry/measurement/NXevent_data_em/eels/summary/axis_energy_loss
# entry/measurement/NXevent_data_em/eels/summary/data_counts
# entry/measurement/NXevent_data_em/eels/summary/title
# entry/measurement/NXevent_data_em/em_lab
# entry/measurement/NXevent_data_em/em_lab/NXchamber
# entry/measurement/NXevent_data_em/em_lab/NXdetector
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXaperture_em
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXaperture_em/value
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXchamber
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXlens_em
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXlens_em/current
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXlens_em/value
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/NXlens_em/voltage
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/NXfabrication
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/NXfabrication/identifier
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/NXfabrication/model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/NXfabrication/vendor
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_1/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_2/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_3/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_4/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/a_6/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_2/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/b_4/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_1/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_3/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/c_5/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/d_4/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/r_5/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_3/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/ceos/s_5/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_0/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_1_2_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_1_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_2_3_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_0/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_2_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_3_4_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_1_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_3_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_4_5_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_0/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_2_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_4_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_a/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/delta_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/magnitude
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/uncertainty
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/NXprocess/nion/c_5_6_b/uncertainty_model
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/description
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/exposure_time
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/magnification
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/tilt_angle
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/applied
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/aberration_correction/name
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/electron_source
# entry/measurement/NXevent_data_em/em_lab/NXebeam_column/electron_source/voltage
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXaperture_em
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXaperture_em/value
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXchamber
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXlens_em
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXlens_em/current
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXlens_em/value
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/NXlens_em/voltage
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source/current
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source/probe
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source/probe/charge_state
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source/probe/isotope_vector
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source/probe/name
# entry/measurement/NXevent_data_em/em_lab/NXibeam_column/ion_source/voltage
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/beam_current
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/beam_current_description
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/camera_length
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/defocus
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/magnification
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/semi_convergence_angle
# entry/measurement/NXevent_data_em/em_lab/NXoptical_system_em/working_distance
# entry/measurement/NXevent_data_em/em_lab/NXpump
# entry/measurement/NXevent_data_em/em_lab/NXstage_lab
# entry/measurement/NXevent_data_em/em_lab/NXstage_lab/position
# entry/measurement/NXevent_data_em/em_lab/NXstage_lab/rotation
# entry/measurement/NXevent_data_em/em_lab/NXstage_lab/tilt_1
# entry/measurement/NXevent_data_em/em_lab/NXstage_lab/tilt_2
# entry/measurement/NXevent_data_em/em_lab/ebeam_deflector
# entry/measurement/NXevent_data_em/em_lab/ebeam_deflector/pixel_time
# entry/measurement/NXevent_data_em/em_lab/ibeam_deflector
# entry/measurement/NXevent_data_em/end_time
# entry/measurement/NXevent_data_em/event_identifier
# entry/measurement/NXevent_data_em/event_type
# entry/measurement/NXevent_data_em/kikuchi
# entry/measurement/NXevent_data_em/kikuchi/NXprocess
# entry/measurement/NXevent_data_em/kikuchi/NXprocess/NXprogram
# entry/measurement/NXevent_data_em/kikuchi/NXprocess/NXprogram/program
# entry/measurement/NXevent_data_em/kikuchi/NXprocess/detector_identifier
# entry/measurement/NXevent_data_em/kikuchi/NXprocess/mode
# entry/measurement/NXevent_data_em/kikuchi/NXprocess/source
# entry/measurement/NXevent_data_em/kikuchi/stack
# entry/measurement/NXevent_data_em/kikuchi/stack/axis_x
# entry/measurement/NXevent_data_em/kikuchi/stack/axis_y
# entry/measurement/NXevent_data_em/kikuchi/stack/data_counts
# entry/measurement/NXevent_data_em/kikuchi/stack/pattern_identifier
# entry/measurement/NXevent_data_em/kikuchi/stack/scan_point_identifier
# entry/measurement/NXevent_data_em/kikuchi/stack/title
# entry/measurement/NXevent_data_em/start_time
# entry/measurement/NXevent_data_em/xray
# entry/measurement/NXevent_data_em/xray/NXprocess
# entry/measurement/NXevent_data_em/xray/NXprocess/NXprogram
# entry/measurement/NXevent_data_em/xray/NXprocess/NXprogram/program
# entry/measurement/NXevent_data_em/xray/NXprocess/detector_identifier
# entry/measurement/NXevent_data_em/xray/NXprocess/mode
# entry/measurement/NXevent_data_em/xray/NXprocess/source
# entry/measurement/NXevent_data_em/xray/indexing
# entry/measurement/NXevent_data_em/xray/indexing/ELEMENTNAME
# entry/measurement/NXevent_data_em/xray/indexing/ELEMENTNAME/summary
# entry/measurement/NXevent_data_em/xray/indexing/ELEMENTNAME/summary/axis_x
# entry/measurement/NXevent_data_em/xray/indexing/ELEMENTNAME/summary/axis_y
# entry/measurement/NXevent_data_em/xray/indexing/ELEMENTNAME/summary/data_counts
# entry/measurement/NXevent_data_em/xray/indexing/ELEMENTNAME/summary/title
# entry/measurement/NXevent_data_em/xray/stack
# entry/measurement/NXevent_data_em/xray/stack/axis_photon_energy
# entry/measurement/NXevent_data_em/xray/stack/axis_x
# entry/measurement/NXevent_data_em/xray/stack/axis_y
# entry/measurement/NXevent_data_em/xray/stack/data_counts
# entry/measurement/NXevent_data_em/xray/stack/title
# entry/measurement/NXevent_data_em/xray/summary
# entry/measurement/NXevent_data_em/xray/summary/axis_photon_energy
# entry/measurement/NXevent_data_em/xray/summary/data_counts
# entry/measurement/NXevent_data_em/xray/summary/title
# entry/sample
# entry/sample/atom_types
# entry/sample/density
# entry/sample/description
# entry/sample/method
# entry/sample/name
# entry/sample/preparation_date
# entry/sample/sample_history
# entry/sample/short_title
# entry/sample/thickness
# entry/start_time
# entry/thumbnail

# %%
from nexusformat.nexus import NXFile

with NXFile("NXem_regenerated.nxs", "r") as f:
    nxroot = f.readfile()
    print(nxroot.tree)
# Out:
# root:NXroot
#   entry:NXentry
#     NXcoordinate_system_set:NXcoordinate_system_set
#       TRANSFORMATIONS:NXtransformations
#     NXdata:NXdata
#     NXmonitor:NXmonitor
#     NXprogram:NXprogram
#       program = 'unset'
#     NXuser:NXuser
#       address = 'unset'
#       affiliation = 'unset'
#       email = 'unset'
#       name = 'unset'
#       orcid = 'unset'
#       orcid_platform = 'unset'
#       role = 'unset'
#       social_media_name = 'unset'
#       social_media_platform = 'unset'
#       telephone_number = 'unset'
#     definition = 'NXem'
#     em_lab:NXinstrument
#       DETECTOR:NXdetector
#         NXfabrication:NXfabrication
#           identifier = 'unset'
#         local_name = 'unset'
#       EBEAM_DEFLECTOR:NXscanbox_em
#         NXfabrication:NXfabrication
#           identifier = 'unset'
#           model = 'unset'
#           vendor = 'unset'
#         pixel_time = 0.0
#       IBEAM_DEFLECTOR:NXscanbox_em
#         NXfabrication:NXfabrication
#           identifier = 'unset'
#           model = 'unset'
#           vendor = 'unset'
#       NXchamber:NXchamber
#       NXebeam_column:NXebeam_column
#         NXaperture_em:NXaperture_em
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#             model = 'unset'
#             vendor = 'unset'
#           description = 'unset'
#           name = 'unset'
#           value = 'unset'
#         NXchamber:NXchamber
#         NXfabrication:NXfabrication
#           identifier = 'unset'
#           model = 'unset'
#           vendor = 'unset'
#         NXlens_em:NXlens_em
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#             model = 'unset'
#             vendor = 'unset'
#           current = 'unset'
#           value = 'unset'
#           voltage = 'unset'
#         aberration_correction:NXcorrector_cs
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#             model = 'unset'
#             vendor = 'unset'
#           ZEMLIN_TABLEAU:NXprocess
#             NXprocess:NXprocess
#               ceos:NXaberration_model_ceos
#                 a_1:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 a_2:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 a_3:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 a_4:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 a_6:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 b_2:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 b_4:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_1:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_3:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 d_4:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 r_5:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 s_3:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 s_5:NXaberration
#                   angle = 0.0
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#               nion:NXaberration_model_nion
#                 c_1_0:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_1_2_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_1_2_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_2_1_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_2_1_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_2_3_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_2_3_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_3_0:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_3_2_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_3_2_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_3_4_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_3_4_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_4_1_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_4_1_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_4_3_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_4_3_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_4_5_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_4_5_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_0:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_2_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_2_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_4_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_4_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_6_a:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#                 c_5_6_b:NXaberration
#                   delta_time = 0.0
#                   magnitude = 0.0
#                   uncertainty = 0.0
#                   uncertainty_model = 'unset'
#             description = 'unset'
#             exposure_time = 0.0
#             magnification = 'unset'
#             tilt_angle = 0.0
#           applied = 'unset'
#           name = 'unset'
#         electron_source:NXsource
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#             model = 'unset'
#             vendor = 'unset'
#           emitter_type = 'unset'
#           name = 'unset'
#           voltage = 0.0
#       NXfabrication:NXfabrication
#         capabilities = 'unset'
#         identifier = 'unset'
#         model = 'unset'
#         vendor = 'unset'
#       NXibeam_column:NXibeam_column
#         NXaperture_em:NXaperture_em
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#             model = 'unset'
#             vendor = 'unset'
#           value = 'unset'
#         NXchamber:NXchamber
#         NXfabrication:NXfabrication
#           identifier = 'unset'
#           model = 'unset'
#           vendor = 'unset'
#         NXlens_em:NXlens_em
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#           current = 'unset'
#           value = 'unset'
#           voltage = 'unset'
#         ion_source:NXsource
#           NXfabrication:NXfabrication
#             identifier = 'unset'
#             model = 'unset'
#             vendor = 'unset'
#           current = 0.0
#           emitter_type = 'unset'
#           name = 'unset'
#           probe:NXion
#             charge_state = 0
#             isotope_vector = 0
#             name = 'unset'
#           voltage = 0.0
#       NXoptical_system_em:NXoptical_system_em
#         beam_current = 0.0
#         beam_current_description = 'unset'
#         camera_length = 'unset'
#         defocus = 'unset'
#         magnification = 'unset'
#         semi_convergence_angle = 'unset'
#         working_distance = 0.0
#       NXpump:NXpump
#       instrument_name = 'unset'
#       location = 'unset'
#       stage_lab:NXstage_lab
#         NXfabrication:NXfabrication
#           capabilities = 'unset'
#           identifier = 'unset'
#           model = 'unset'
#           vendor = 'unset'
#         description = 'unset'
#         design = 'unset'
#         name = 'unset'
#         position = 0.0
#         rotation = 0.0
#         tilt_1 = 0.0
#         tilt_2 = 0.0
#     end_time = 'unset'
#     experiment_description = 'unset'
#     experiment_documentation:NXnote
#     experiment_identifier = 'unset'
#     measurement:NXevent_data_em_set
#       NXevent_data_em:NXevent_data_em
#         IMAGE_SET:NXimage_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#               program = 'unset'
#             detector_identifier = 'unset'
#             mode = 'unset'
#             source = 'unset'
#           stack:NXdata
#             axis_image_identifier = 0
#             axis_x = 'unset'
#             axis_y = 'unset'
#             data_counts = 'unset'
#             title = 'unset'
#         NXuser:NXuser
#           name = 'unset'
#         SPECTRUM_SET:NXspectrum_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#               program = 'unset'
#             detector_identifier = 'unset'
#             mode = 'unset'
#             source = 'unset'
#           stack:NXdata
#             axis_energy = 'unset'
#             axis_x = 'unset'
#             axis_y = 'unset'
#             data_counts = 'unset'
#           summary:NXdata
#             axis_energy = 'unset'
#             data_counts = 'unset'
#         adf:NXimage_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#               program = 'unset'
#             detector_identifier = 'unset'
#             mode = 'unset'
#             source = 'unset'
#           inner_half_angle = 0.0
#           outer_half_angle = 0.0
#           stack:NXdata
#             axis_image_identifier = 0
#             axis_x = 'unset'
#             axis_y = 'unset'
#             data_counts = 'unset'
#             title = 'unset'
#         eels:NXspectrum_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#               program = 'unset'
#             detector_identifier = 'unset'
#             mode = 'unset'
#             source = 'unset'
#           stack:NXdata
#             axis_energy_loss = 'unset'
#             axis_x = 'unset'
#             axis_y = 'unset'
#             data_counts = 'unset'
#             title = 'unset'
#           summary:NXdata
#             axis_energy_loss = 'unset'
#             data_counts = 'unset'
#             title = 'unset'
#         em_lab:NXinstrument
#           NXchamber:NXchamber
#           NXdetector:NXdetector
#           NXebeam_column:NXebeam_column
#             NXaperture_em:NXaperture_em
#               value = 'unset'
#             NXchamber:NXchamber
#             NXlens_em:NXlens_em
#               current = 'unset'
#               value = 'unset'
#               voltage = 'unset'
#             aberration_correction:NXcorrector_cs
#               NXfabrication:NXfabrication
#                 identifier = 'unset'
#                 model = 'unset'
#                 vendor = 'unset'
#               ZEMLIN_TABLEAU:NXprocess
#                 NXprocess:NXprocess
#                   ceos:NXaberration_model_ceos
#                     a_1:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     a_2:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     a_3:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     a_4:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     a_6:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     b_2:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     b_4:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_1:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_3:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     d_4:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     r_5:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     s_3:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     s_5:NXaberration
#                       angle = 0.0
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                   nion:NXaberration_model_nion
#                     c_1_0:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_1_2_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_1_2_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_2_1_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_2_1_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_2_3_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_2_3_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_3_0:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_3_2_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_3_2_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_3_4_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_3_4_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_4_1_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_4_1_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_4_3_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_4_3_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_4_5_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_4_5_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_0:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_2_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_2_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_4_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_4_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_6_a:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                     c_5_6_b:NXaberration
#                       delta_time = 0.0
#                       magnitude = 0.0
#                       uncertainty = 0.0
#                       uncertainty_model = 'unset'
#                 description = 'unset'
#                 exposure_time = 0.0
#                 magnification = 'unset'
#                 tilt_angle = 0.0
#               applied = 'unset'
#               name = 'unset'
#             electron_source:NXsource
#               voltage = 0.0
#           NXibeam_column:NXibeam_column
#             NXaperture_em:NXaperture_em
#               value = 'unset'
#             NXchamber:NXchamber
#             NXlens_em:NXlens_em
#               current = 'unset'
#               value = 'unset'
#               voltage = 'unset'
#             ion_source:NXsource
#               current = 0.0
#               probe:NXion
#                 charge_state = 0
#                 isotope_vector = 0
#                 name = 'unset'
#               voltage = 0.0
#           NXoptical_system_em:NXoptical_system_em
#             beam_current = 0.0
#             beam_current_description = 'unset'
#             camera_length = 'unset'
#             defocus = 'unset'
#             magnification = 'unset'
#             semi_convergence_angle = 'unset'
#             working_distance = 0.0
#           NXpump:NXpump
#           NXstage_lab:NXstage_lab
#             position = 0.0
#             rotation = 0.0
#             tilt_1 = 0.0
#             tilt_2 = 0.0
#           ebeam_deflector:NXscanbox_em
#             pixel_time = 0.0
#           ibeam_deflector:NXscanbox_em
#         end_time = 'unset'
#         event_identifier = 'unset'
#         event_type = 'unset'
#         kikuchi:NXimage_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#               program = 'unset'
#             detector_identifier = 'unset'
#             mode = 'unset'
#             source = 'unset'
#           stack:NXdata
#             axis_x = 'unset'
#             axis_y = 'unset'
#             data_counts = 'unset'
#             pattern_identifier = 0
#             scan_point_identifier = 0
#             title = 'unset'
#         start_time = 'unset'
#         xray:NXspectrum_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#               program = 'unset'
#             detector_identifier = 'unset'
#             mode = 'unset'
#             source = 'unset'
#           indexing:NXprocess
#             ELEMENTNAME:NXprocess
#               summary:NXdata
#                 axis_x = 'unset'
#                 axis_y = 'unset'
#                 data_counts = 'unset'
#                 title = 'unset'
#           stack:NXdata
#             axis_photon_energy = 'unset'
#             axis_x = 'unset'
#             axis_y = 'unset'
#             data_counts = 'unset'
#             title = 'unset'
#           summary:NXdata
#             axis_photon_energy = 'unset'
#             data_counts = 'unset'
#             title = 'unset'
#     sample:NXsample
#       atom_types = 'unset'
#       density = 0.0
#       description = 'unset'
#       method = 'unset'
#       name = 'unset'
#       preparation_date = 'unset'
#       sample_history = 'unset'
#       short_title = 'unset'
#       thickness = 0.0
#     start_time = 'unset'
#     thumbnail:NXnote

# %% [markdown]
# # Reading+Mapping Metadata of Tescan Amber X

# %%
import os
import h5py
import json
import numpy as np
import tifffile
import imageio.v3 as iio
from configparser import ConfigParser

# --- CONFIGURATION ---
INPUT_IMAGE_FILE = "tescan_image.png"        # Could also be .tif or .tiff
OUTPUT_NEXUS_FILE = "tescan_output.nxs"

# --- MAPPING: Tescan metadata keys => NeXus paths ---
mapping = {
  # ––– MAIN –––
  "MAIN.AccFrames":    "entry/NXmonitor/value",
  "MAIN.AccType":      None,
  "MAIN.Company":      "entry/em_lab/NXfabrication/vendor",
  "MAIN.Date":         "entry/start_time",
  "MAIN.Description":  "entry/em_lab/NXebeam_column/NXaperture_em/description",
  "MAIN.Device":       "entry/em_lab/instrument_name",
  "MAIN.DeviceModel":  "entry/em_lab/NXfabrication/model",
  "MAIN.FullUserName": "entry/NXuser/name",
  "MAIN.ImageStripSize": None,
  "MAIN.Magnification":          "entry/em_lab/NXoptical_system_em/magnification",
  "MAIN.MagnificationReference": "entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/magnification",
  "MAIN.OrigFileName":  None,
  "MAIN.PixelSizeX":    "entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_x",
  "MAIN.PixelSizeY":    "entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_y",
  "MAIN.SerialNumber":  "entry/em_lab/NXfabrication/identifier",
  "MAIN.Sign":          None,
  "MAIN.SoftwareVersion":"entry/NXprogram/program",
  "MAIN.Time":          "entry/start_time",
  "MAIN.UserName":      "entry/NXuser/name",
  "MAIN.ViewFieldsCountX": None,
  "MAIN.ViewFieldsCountY": None,

  # ––– FIB –––
  "FIB.ChamberPressure":   "entry/em_lab/NXchamber/pressure",
  "FIB.ColumnPressure":    "entry/em_lab/NXebeam_column/NXchamber/pressure",
  "FIB.ColumnTilt":        "entry/em_lab/NXstage_lab/tilt_1",
  "FIB.ColumnType":        None,
  "FIB.Condenser":         "entry/em_lab/NXebeam_column/NXlens_em/current",
  "FIB.Detector":          "entry/em_lab/DETECTOR/local_name",
  "FIB.Detector0":         "entry/em_lab/DETECTOR/local_name",
  "FIB.Detector0FlatField": None,
  "FIB.Detector0Gain":      None,
  "FIB.Detector0Offset":    None,
  "FIB.DwellTime":          "entry/em_lab/EBEAM_DEFLECTOR/pixel_time",
  "FIB.EmissionCurrent":    "entry/em_lab/NXibeam_column/ion_source/current",
  "FIB.Extractor":          "entry/em_lab/NXibeam_column/ion_source/voltage",
  "FIB.GunPressure":        None,
  "FIB.HV":                 "entry/em_lab/NXebeam_column/electron_source/voltage",
  "FIB.ImageShiftX":        None,
  "FIB.ImageShiftY":        None,
  "FIB.LUTGamma":           None,
  "FIB.LUTMaximum":         None,
  "FIB.LUTMinimum":         None,
  "FIB.LastPreset":         None,
  "FIB.Objective":          "entry/em_lab/NXebeam_column/NXlens_em/value",
  "FIB.PredictedBeamCurrent": None,
  "FIB.PresetAlignmentX":   None,
  "FIB.PresetAlignmentY":   None,
  "FIB.PrimaryDetectorGain": None,
  "FIB.PrimaryDetectorOffset": None,
  "FIB.ProbeApertureDiameter": "entry/em_lab/NXebeam_column/NXaperture_em/value",
  "FIB.ProbeApertureIndex":    "entry/em_lab/NXebeam_column/NXaperture_em/name",
  "FIB.ProbeApertureLabel":    "entry/em_lab/NXebeam_column/NXaperture_em/name",
  "FIB.ProbeAperturePositionX": None,
  "FIB.ProbeAperturePositionY": None,
  "FIB.ScanID":               "entry/measurement/NXevent_data_em/event_identifier",
  "FIB.ScanRotation":         "entry/em_lab/NXstage_lab/rotation",
  "FIB.ScanSpeed":            None,
  "FIB.SessionID":            "entry/measurement/NXevent_data_em/event_identifier",
  "FIB.SpotSize":             None,
  "FIB.StageRotation":        "entry/em_lab/NXstage_lab/rotation",
  "FIB.StageTilt":            "entry/em_lab/NXstage_lab/tilt_1",
  "FIB.StageX":               "entry/em_lab/NXstage_lab/position",
  "FIB.StageY":               "entry/em_lab/NXstage_lab/position",
  "FIB.StageZ":               "entry/em_lab/NXstage_lab/position",
  "FIB.StigmatorX":           None,
  "FIB.StigmatorY":           None,
  "FIB.TiltCorrection":       "entry/em_lab/NXebeam_column/aberration_correction/tilt_angle",
  "FIB.WD":                   "entry/em_lab/NXoptical_system_em/working_distance"
}
# ✅ Fix: replace dots with slashes in NeXus paths
# MAPPING_DICT = {k: v.replace('.', '/') for k, v in json.loads(MAPPING_JSON).items()}

# --- PARSE Tescan INI-style METADATA ---
def parse_ini_metadata(ini_text):
    parser = ConfigParser()
    parser.optionxform = str  # preserve case
    parser.read_string(ini_text)

    metadata = {}
    for section in parser.sections():
        for key, val in parser.items(section):
            full_key = f"{section}.{key}"
            metadata[full_key] = val
    return metadata

# --- ENSURE GROUP EXISTS ---
def ensure_hdf5_group(h5file, path):
    parts = path.strip('/').split('/')
    grp = h5file
    for part in parts:
        if part not in grp:
            grp = grp.create_group(part)
        else:
            grp = grp[part]
    return grp

# --- READ IMAGE + METADATA (.tif or .png+.hdr) ---
def read_image_and_metadata(filepath):
    ext = os.path.splitext(filepath)[-1].lower()
    base = os.path.splitext(filepath)[0]

    if ext in ['.tif', '.tiff']:
        with tifffile.TiffFile(filepath) as tif:
            page = tif.pages[0]
            image_data = page.asarray()
            metadata_dict = {}

            desc_tag = page.tags.get("ImageDescription")
            if desc_tag:
                ini_text = desc_tag.value
                metadata_dict = parse_ini_metadata(ini_text)

        return image_data, metadata_dict

    elif ext == '.png':
        image_data = iio.imread(filepath)

        hdr_path = base + ".hdr"
        if not os.path.exists(hdr_path):
            raise FileNotFoundError(f"No metadata file found at: {hdr_path}")

        with open(hdr_path, "r", encoding="utf-8") as f:
            ini_text = f.read()
        metadata_dict = parse_ini_metadata(ini_text)

        return image_data, metadata_dict

    else:
        raise ValueError(f"Unsupported image format: {ext}")

# %%
image, metadata = read_image_and_metadata(INPUT_IMAGE_FILE)
print("✅ Loaded image with shape:", image.shape)
print("✅ Parsed metadata keys (sample):", list(metadata.keys())[:])
print("✅ Total metadata entries:", len(metadata))
# Out:
# ✅ Loaded image with shape: (1104, 1024)
# ✅ Parsed metadata keys (sample): ['MAIN.AccFrames', 'MAIN.AccType', 'MAIN.Company', 'MAIN.Date', 'MAIN.Description', 'MAIN.Device', 'MAIN.DeviceModel', 'MAIN.FullUserName', 'MAIN.ImageStripSize', 'MAIN.Magnification', 'MAIN.MagnificationReference', 'MAIN.OrigFileName', 'MAIN.PixelSizeX', 'MAIN.PixelSizeY', 'MAIN.SerialNumber', 'MAIN.Sign', 'MAIN.SoftwareVersion', 'MAIN.Time', 'MAIN.UserName', 'MAIN.ViewFieldsCountX', 'MAIN.ViewFieldsCountY', 'FIB.ChamberPressure', 'FIB.ColumnPressure', 'FIB.ColumnTilt', 'FIB.ColumnType', 'FIB.Condenser', 'FIB.Detector', 'FIB.Detector0', 'FIB.Detector0FlatField', 'FIB.Detector0Gain', 'FIB.Detector0Offset', 'FIB.DwellTime', 'FIB.EmissionCurrent', 'FIB.Extractor', 'FIB.GunPressure', 'FIB.HV', 'FIB.ImageShiftX', 'FIB.ImageShiftY', 'FIB.LUTGamma', 'FIB.LUTMaximum', 'FIB.LUTMinimum', 'FIB.LastPreset', 'FIB.Objective', 'FIB.PredictedBeamCurrent', 'FIB.PresetAlignmentX', 'FIB.PresetAlignmentY', 'FIB.PrimaryDetectorGain', 'FIB.PrimaryDetectorOffset', 'FIB.ProbeApertureDiameter', 'FIB.ProbeApertureIndex', 'FIB.ProbeApertureLabel', 'FIB.ProbeAperturePositionX', 'FIB.ProbeAperturePositionY', 'FIB.ScanID', 'FIB.ScanRotation', 'FIB.ScanSpeed', 'FIB.SessionID', 'FIB.SpotSize', 'FIB.StageRotation', 'FIB.StageTilt', 'FIB.StageX', 'FIB.StageY', 'FIB.StageZ', 'FIB.StigmatorX', 'FIB.StigmatorY', 'FIB.TiltCorrection', 'FIB.WD']
# ✅ Total metadata entries: 67

# %% [markdown]
# # Combining two Scripts
# (creating Nexus file from data and metadata of Tescan)

# %%
"""
tescan_to_nexus.py
-------------------------------------------
Build blank NXem, read Tescan image + metadata,
write both into a NeXus file without size limits.
"""

# ───────── paths ─────────
NXDL_FILE         = "NXem.nxdl.xml"
INPUT_IMAGE_FILE  = "tescan_image.png"   # .png(+hdr) or .tif
OUTPUT_NEXUS_FILE = "tescan_output.nxs"

# ───────── imports ─────────
import os, numpy as np, h5py, tifffile, imageio.v3 as iio
from lxml import etree
from configparser import ConfigParser

# ───────── mapping (unchanged) ─────────
mapping = {
  "MAIN.AccFrames":                 "entry/NXmonitor/value",
  "MAIN.AccType":                   None,
  "MAIN.Company":                   "entry/em_lab/NXfabrication/vendor",
  "MAIN.Date":                      "entry/start_time",
  "MAIN.Description":               "entry/em_lab/NXebeam_column/NXaperture_em/description",
  "MAIN.Device":                    "entry/em_lab/instrument_name",
  "MAIN.DeviceModel":               "entry/em_lab/NXfabrication/model",
  "MAIN.FullUserName":              "entry/NXuser/name",
  "MAIN.ImageStripSize":            None,
  "MAIN.Magnification":             "entry/em_lab/NXoptical_system_em/magnification",
  "MAIN.MagnificationReference":    "entry/em_lab/NXebeam_column/aberration_correction/ZEMLIN_TABLEAU/magnification",
  "MAIN.OrigFileName":              None,
  "MAIN.PixelSizeX":                "entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_x",
  "MAIN.PixelSizeY":                "entry/measurement/NXevent_data_em/IMAGE_SET/stack/axis_y",
  "MAIN.SerialNumber":              "entry/em_lab/NXfabrication/identifier",
  "MAIN.SoftwareVersion":           "entry/NXprogram/program",
  "MAIN.Time":                      "entry/start_time",
  "MAIN.UserName":                  "entry/NXuser/name",

  "FIB.ChamberPressure":            "entry/em_lab/NXchamber/pressure",
  "FIB.ColumnPressure":             "entry/em_lab/NXebeam_column/NXchamber/pressure",
  "FIB.ColumnTilt":                 "entry/em_lab/NXstage_lab/tilt_1",
  "FIB.Condenser":                  "entry/em_lab/NXebeam_column/NXlens_em/current",
  "FIB.Detector":                   "entry/em_lab/DETECTOR/local_name",
  "FIB.DwellTime":                  "entry/em_lab/EBEAM_DEFLECTOR/pixel_time",
  "FIB.EmissionCurrent":            "entry/em_lab/NXibeam_column/ion_source/current",
  "FIB.Extractor":                  "entry/em_lab/NXibeam_column/ion_source/voltage",
  "FIB.HV":                         "entry/em_lab/NXebeam_column/electron_source/voltage",
  "FIB.Objective":                  "entry/em_lab/NXebeam_column/NXlens_em/value",
  "FIB.ProbeApertureDiameter":      "entry/em_lab/NXebeam_column/NXaperture_em/value",
  "FIB.ProbeApertureIndex":         "entry/em_lab/NXebeam_column/NXaperture_em/name",
  "FIB.ScanID":                     "entry/measurement/NXevent_data_em/event_identifier",
  "FIB.ScanRotation":               "entry/em_lab/NXstage_lab/rotation",
  "FIB.SessionID":                  "entry/measurement/NXevent_data_em/event_identifier",
  "FIB.StageRotation":              "entry/em_lab/NXstage_lab/rotation",
  "FIB.StageTilt":                  "entry/em_lab/NXstage_lab/tilt_1",
  "FIB.StageX":                     "entry/em_lab/NXstage_lab/position",
  "FIB.StageY":                     "entry/em_lab/NXstage_lab/position",
  "FIB.StageZ":                     "entry/em_lab/NXstage_lab/position",
  "FIB.TiltCorrection":             "entry/em_lab/NXebeam_column/aberration_correction/tilt_angle",
  "FIB.WD":                         "entry/em_lab/NXoptical_system_em/working_distance"
}


# ───────── helpers ─────────
def parse_ini(txt:str)->dict:
    cp=ConfigParser(); cp.optionxform=str; cp.read_string(txt)
    return {f"{s}.{k}":v for s in cp.sections() for k,v in cp.items(s)}

def ensure_grp(h: h5py.Group, p:str)->h5py.Group:
    g=h
    for part in p.strip("/").split("/"):
        g=g.require_group(part)
    return g

# ───────── 1. safer blank builder ─────────
def build_blank(nxdl:str, outnxs:str):
    ns={"nx":"http://definition.nexusformat.org/nxdl/3.1"}
    root=etree.parse(nxdl).getroot()
    entry=root.find(".//nx:group[@type='NXentry']",ns)
    if entry is None: raise RuntimeError("NXentry not found")

    # collect all nested <group> nodes
    groups=[]
    def visit(node):
        for el in node:
            if isinstance(el.tag,str) and etree.QName(el.tag).localname=="group":
                groups.append(el); visit(el)
    visit(entry)

    with h5py.File(outnxs,"w") as f:
        ent=ensure_grp(f,"/entry"); ent.attrs["NX_class"]="NXentry"
        ent.create_dataset("definition",
                           data=np.bytes_("NXem"),
                           dtype=h5py.string_dtype("utf-8"))

        for g in groups:
            # build path components up to NXentry
            comps=[]
            n=g
            while n is not None and n is not entry:
                comps.append(n.get("name") or n.get("type"))
                n=n.getparent()
            comps.reverse()
            grp=ensure_grp(f,"/entry/" + "/".join(comps))
            if g.get("type"):
                grp.attrs["NX_class"]=g.get("type")

# ───────── 2. read Tescan (unchanged) ─────────
def read_tescan(path:str):
    base,ext=os.path.splitext(path); ext=ext.lower()
    if ext in(".tif",".tiff"):
        with tifffile.TiffFile(path) as tf:
            img=tf.pages[0].asarray()
            meta={}
            tag=tf.pages[0].tags.get("ImageDescription")
            if tag: meta.update(parse_ini(tag.value))
        return img,meta
    if ext==".png":
        img=iio.imread(path)
        hdr=base+".hdr"
        if not os.path.exists(hdr): raise FileNotFoundError(hdr)
        return img,parse_ini(open(hdr,encoding="utf-8").read())
    raise ValueError("unsupported")

# ───────── scalar helpers ─────────
def to_scalar(v:str):
    try:
        f=float(v); return int(f) if f.is_integer() else f
    except Exception: return v.encode()

def write_scalar(parent: h5py.Group,name:str,val):
    if name in parent:
        ds=parent[name]
        need_new=False
        if isinstance(val,(bytes,str)):
            if not h5py.check_string_dtype(ds.dtype): need_new=True
            elif h5py.check_string_dtype(ds.dtype).length and \
                 len(val)>ds.dtype.itemsize:         need_new=True
        else:
            if h5py.check_string_dtype(ds.dtype):    need_new=True
        if need_new:
            del parent[name]
            return write_scalar(parent,name,val)
        ds[...]=val
    else:
        if isinstance(val,(bytes,str)):
            parent.create_dataset(name,data=val,dtype=h5py.string_dtype("utf-8"))
        else:
            parent.create_dataset(name,data=val)

# ───────── 3. fill file (unchanged logic) ─────────
def fill_nexus(nxs:str,img,npmeta,mp):
    with h5py.File(nxs,"a") as f:
        nxdata=ensure_grp(f,"/entry/data"); nxdata.attrs.update({"NX_class":"NXdata","signal":"data"})
        if "data" in nxdata: nxdata["data"][...]=img
        else: nxdata.create_dataset("data",data=img)

        for k,p in mp.items():
            if p is None or k not in npmeta: continue
            parent_path,dname=os.path.split(p)
            parent=ensure_grp(f,parent_path)
            if dname in parent and isinstance(parent[dname],h5py.Group):
                parent=parent[dname]; dname="value"
            write_scalar(parent,dname,to_scalar(npmeta[k]))

# ───────── main ─────────
if __name__=="__main__":
    build_blank(NXDL_FILE,OUTPUT_NEXUS_FILE)
    print("blank NXem built")

    img,meta=read_tescan(INPUT_IMAGE_FILE)
    print("read Tescan:",img.shape,"meta",len(meta))

    fill_nexus(OUTPUT_NEXUS_FILE,img,meta,mapping)
    print("done ->",OUTPUT_NEXUS_FILE)
# Out:
# blank NXem built
# read Tescan: (1104, 1024) meta 67
# done -> tescan_output.nxs

# %%
from nexusformat.nexus import NXFile

with NXFile("tescan_output.nxs", "r") as f:
    nxroot = f.readfile()
    print(nxroot.tree)
# Out:
# root:NXroot
#   entry:NXentry
#     NXcoordinate_system_set:NXcoordinate_system_set
#       TRANSFORMATIONS:NXtransformations
#     NXdata:NXdata
#     NXmonitor:NXmonitor
#       value = 2
#     NXprogram:NXprogram
#       program = 'TESCAN Essence Version 1.3.1.0, build 7450'
#     NXuser:NXuser
#       name = 'LAME_Supervisor'
#     data:NXdata
#       @signal = 'data'
#       data = uint16(1104x1024)
#     definition = 'NXem'
#     em_lab:NXinstrument
#       DETECTOR:NXdetector
#         NXfabrication:NXfabrication
#         local_name = 'SE'
#       EBEAM_DEFLECTOR:NXscanbox_em
#         NXfabrication:NXfabrication
#         pixel_time = 1e-06
#       IBEAM_DEFLECTOR:NXscanbox_em
#         NXfabrication:NXfabrication
#       NXchamber:NXchamber
#         pressure = 0.00162483
#       NXebeam_column:NXebeam_column
#         NXaperture_em:NXaperture_em
#           NXfabrication:NXfabrication
#           description = ''
#           name = 16
#           value = 5e-05
#         NXchamber:NXchamber
#           pressure = 0.00011
#         NXfabrication:NXfabrication
#         NXlens_em:NXlens_em
#           NXfabrication:NXfabrication
#           current = 20901.9
#           value = 17530.5
#         aberration_correction:NXcorrector_cs
#           NXfabrication:NXfabrication
#           ZEMLIN_TABLEAU:NXprocess
#             NXprocess:NXprocess
#               ceos:NXaberration_model_ceos
#                 a_1:NXaberration
#                 a_2:NXaberration
#                 a_3:NXaberration
#                 a_4:NXaberration
#                 a_6:NXaberration
#                 b_2:NXaberration
#                 b_4:NXaberration
#                 c_1:NXaberration
#                 c_3:NXaberration
#                 c_5:NXaberration
#                 d_4:NXaberration
#                 r_5:NXaberration
#                 s_3:NXaberration
#                 s_5:NXaberration
#               nion:NXaberration_model_nion
#                 c_1_0:NXaberration
#                 c_1_2_a:NXaberration
#                 c_1_2_b:NXaberration
#                 c_2_1_a:NXaberration
#                 c_2_1_b:NXaberration
#                 c_2_3_a:NXaberration
#                 c_2_3_b:NXaberration
#                 c_3_0:NXaberration
#                 c_3_2_a:NXaberration
#                 c_3_2_b:NXaberration
#                 c_3_4_a:NXaberration
#                 c_3_4_b:NXaberration
#                 c_4_1_a:NXaberration
#                 c_4_1_b:NXaberration
#                 c_4_3_a:NXaberration
#                 c_4_3_b:NXaberration
#                 c_4_5_a:NXaberration
#                 c_4_5_b:NXaberration
#                 c_5_0:NXaberration
#                 c_5_2_a:NXaberration
#                 c_5_2_b:NXaberration
#                 c_5_4_a:NXaberration
#                 c_5_4_b:NXaberration
#                 c_5_6_a:NXaberration
#                 c_5_6_b:NXaberration
#             magnification = 0.2792
#           tilt_angle = 0
#         electron_source:NXsource
#           NXfabrication:NXfabrication
#           voltage = 30000
#       NXfabrication:NXfabrication
#         identifier = '123-0245'
#         model = 'S8254X'
#         vendor = ''
#       NXibeam_column:NXibeam_column
#         NXaperture_em:NXaperture_em
#           NXfabrication:NXfabrication
#         NXchamber:NXchamber
#         NXfabrication:NXfabrication
#         NXlens_em:NXlens_em
#           NXfabrication:NXfabrication
#         ion_source:NXsource
#           NXfabrication:NXfabrication
#           current = 6.109e-06
#           probe:NXion
#           voltage = 800.1
#       NXoptical_system_em:NXoptical_system_em
#         magnification = 249.94149829
#         working_distance = 0.012
#       NXpump:NXpump
#       NXstage_lab:NXgroup
#         position = 0.02914755
#         rotation = 187
#         tilt_1 = 0
#       instrument_name = 'TESCAN AMBER X'
#       stage_lab:NXstage_lab
#         NXfabrication:NXfabrication
#     experiment_documentation:NXnote
#     measurement:NXevent_data_em_set
#       NXevent_data_em:NXevent_data_em
#         IMAGE_SET:NXimage_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#           stack:NXdata
#             axis_x = 1.090880273e-06
#             axis_y = 1.090880273e-06
#         NXuser:NXuser
#         SPECTRUM_SET:NXspectrum_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#           stack:NXdata
#           summary:NXdata
#         adf:NXimage_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#           stack:NXdata
#         eels:NXspectrum_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#           stack:NXdata
#           summary:NXdata
#         em_lab:NXinstrument
#           NXchamber:NXchamber
#           NXdetector:NXdetector
#           NXebeam_column:NXebeam_column
#             NXaperture_em:NXaperture_em
#             NXchamber:NXchamber
#             NXlens_em:NXlens_em
#             aberration_correction:NXcorrector_cs
#               NXfabrication:NXfabrication
#               ZEMLIN_TABLEAU:NXprocess
#                 NXprocess:NXprocess
#                   ceos:NXaberration_model_ceos
#                     a_1:NXaberration
#                     a_2:NXaberration
#                     a_3:NXaberration
#                     a_4:NXaberration
#                     a_6:NXaberration
#                     b_2:NXaberration
#                     b_4:NXaberration
#                     c_1:NXaberration
#                     c_3:NXaberration
#                     c_5:NXaberration
#                     d_4:NXaberration
#                     r_5:NXaberration
#                     s_3:NXaberration
#                     s_5:NXaberration
#                   nion:NXaberration_model_nion
#                     c_1_0:NXaberration
#                     c_1_2_a:NXaberration
#                     c_1_2_b:NXaberration
#                     c_2_1_a:NXaberration
#                     c_2_1_b:NXaberration
#                     c_2_3_a:NXaberration
#                     c_2_3_b:NXaberration
#                     c_3_0:NXaberration
#                     c_3_2_a:NXaberration
#                     c_3_2_b:NXaberration
#                     c_3_4_a:NXaberration
#                     c_3_4_b:NXaberration
#                     c_4_1_a:NXaberration
#                     c_4_1_b:NXaberration
#                     c_4_3_a:NXaberration
#                     c_4_3_b:NXaberration
#                     c_4_5_a:NXaberration
#                     c_4_5_b:NXaberration
#                     c_5_0:NXaberration
#                     c_5_2_a:NXaberration
#                     c_5_2_b:NXaberration
#                     c_5_4_a:NXaberration
#                     c_5_4_b:NXaberration
#                     c_5_6_a:NXaberration
#                     c_5_6_b:NXaberration
#             electron_source:NXsource
#           NXibeam_column:NXibeam_column
#             NXaperture_em:NXaperture_em
#             NXchamber:NXchamber
#             NXlens_em:NXlens_em
#             ion_source:NXsource
#               probe:NXion
#           NXoptical_system_em:NXoptical_system_em
#           NXpump:NXpump
#           NXstage_lab:NXstage_lab
#           ebeam_deflector:NXscanbox_em
#           ibeam_deflector:NXscanbox_em
#         event_identifier = '57b857b9-f492-4243-a889-c67166633156'
#         kikuchi:NXimage_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#           stack:NXdata
#         xray:NXspectrum_set
#           NXprocess:NXprocess
#             NXprogram:NXprogram
#           indexing:NXprocess
#             ELEMENTNAME:NXprocess
#               summary:NXdata
#           stack:NXdata
#           summary:NXdata
#     sample:NXsample
#     start_time = '14:30:38'
#     thumbnail:NXnote
