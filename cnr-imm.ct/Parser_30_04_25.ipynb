# %%
# Parser unificato e robusto per run_PVD_SiC + analyze_PVD_SiC → NeXus
import os, subprocess, datetime, traceback
import numpy as np
import h5py
from pymulskips import setuprun, process
from pymulskips.analyze import analyze_growth_rate
from analyze_PVD_SiC import count_vacancies

# Funzione helper per dataset con unità
def set_ds(group, name, value, unit=None):
    ds = group.create_dataset(name, data=value)
    if unit:
        ds.attrs['units'] = unit
    return ds

# === INPUT DINAMICO ===
def ask_value(prompt, default, cast):
    val = input(f"{prompt} [default: {default}]: ")
    return cast(val) if val.strip() else default

sample_id = ask_value("ID del campione", '153', str)
lenx = ask_value("Lunghezza X", 120, int)
leny = ask_value("Lunghezza Y", 120, int)
lenz = ask_value("Lunghezza Z", 480, int)
randseed = ask_value("Seed random", 9117116, int)
newdT = ask_value("Delta T aggiuntivo (newdT)", 0, float)
dT = ask_value("Delta T da aggiungere a Tsource", 100, float)
method = ask_value("Metodo di analisi (polyfit o average)", 'polyfit', str)
bin_size = ask_value("Bin size (cm)", 0.001, float)
surface_roughness = ask_value("Filtro rugosità superficie", 0.5, float)
Nexclude = ask_value("Nexclude (default 3)", 3, int)

# === COSTANTI E PARAMETRI ===
execpath = '/Users/filipporuberto/miniforge3/envs/mulskips_env/MulSKIPS/mulskips-source'
DATA_SAMPLES = {
    '153': {
        'Power': 6.10,
        'T_seed_middle': 2072.24,
        'T_seed_edge': 0,
        'T_source_middle': 2080.20,
        'T_source_edge': 2080.20,
        'Exp-Growth-Rate': 287
    }
}
data = dict(DATA_SAMPLES[sample_id])
tseed = data['T_seed_middle'] + 273.15 + newdT
tsource_0 = data['T_source_middle'] + 273.15 + newdT
tsource = tsource_0 + dT
gr = data['Exp-Growth-Rate'] * (dT / 25 if dT != 0 else 1)
KMC_lattice_constant = 0.436 / 12
alat = 5.43
target_thickness = 0.9 * lenz * KMC_lattice_constant * 1e-3
tottime = 3600 * target_thickness / gr
Nout = 90
runpath = f"parser/data-{dT}-{newdT}-{randseed}"
os.makedirs(runpath, exist_ok=True)

# === RUN MULSKIPS ===
setuprun.setup_mulskips_src(execpath, lenx, leny, lenz)
pvdclass = process.PVD(substrate='SiC-3C', precursors=['Si', 'Si2C', 'SiC2'], calibration_type='avrov', Tsource=tsource, Tseed_center=tseed)
setuprun.RunType = 'R'
setuprun.IDUM = randseed
setuprun.setup_only = False
setuprun.TotTime = tottime
setuprun.OutTime = tottime / Nout
setuprun.OutMolMol = 1
setuprun.Seed_box = [48, 0, 0]
setuprun.run_mulskips(execpath, runpath, 'F', pvdclass, PtransZig=0.93, ExitStrategy='Time', SaveCoo=False)

# === ANALISI ===
surf_file = os.path.join(runpath, "surf_height.txt")
xyz_file = os.path.join(runpath, f"{randseed}_v.xyz")
results_file = os.path.join(runpath, "results.txt")
logfile = os.path.join(runpath, "runlog.txt")

try:
    growth_rate, avg_surf_height = analyze_growth_rate(runpath, method=method, return_surf_height=True,
                                                       surface_roughness=surface_roughness, bin_size=bin_size,
                                                       Nexclude=Nexclude)
except Exception as e:
    print(f"⚠️ Growth rate fallita: {e}")
    growth_rate, avg_surf_height = np.nan, np.nan

vac_data = count_vacancies(runpath)

try:
    subprocess.run(f"cat {runpath}/start.dat > {logfile}", shell=True, check=True)
except Exception as e:
    print(f"⚠️ Log fallito: {e}")

def read_file(path, fallback="null"):
    try:
        with open(path, 'r') as f:
            return f.read()
    except:
        print(f"⚠️ File mancante: {path}")
        return fallback

xyz_txt = read_file(xyz_file)
results_txt = read_file(results_file)
log_txt = read_file(logfile)

# === SCRITTURA NEXUS ===
nexus_file = f"SiC_sample_{sample_id}.nxs"
try:
    with h5py.File(nexus_file, 'w') as f:
        f.attrs['NX_class'] = 'NXroot'
        f.create_dataset('default', data=b'NXmicrostructure_imm_results')

        def grp(name):
            g = f.create_group(name)
            g.attrs['NX_class'] = name
            return g

        software = grp('NXsoftware')
        set_ds(software, 'name', b'MulSKIPS')
        set_ds(software, 'version', b'1.0')
        set_ds(software, 'description', b'Multiscale KMC for PVD SiC')

        user = grp('NXuser')
        set_ds(user, 'name', b'Filippo Ruberto')
        set_ds(user, 'affiliation', b'CNR-IMM@CT')
        set_ds(user, 'email', b'filippo.ruberto@cnr.it')
        set_ds(user, 'ORCID', b'0000-0002-1234-5678')

        project = grp('NXproject')
        set_ds(project, 'name', b'MulSKIPS@CNR-IMM')
        set_ds(project, 'description', b'Multiscale modeling of PVD growth of SiC')
        set_ds(project, 'grant_number', b'FAIRmat-NFDI')

        prov = grp('NXprovenance')
        set_ds(prov, 'source', b'https://github.com/mulskips/mulskips-source')
        set_ds(prov, 'modification_date', str(datetime.datetime.now()))

        conf = grp('NXmicrostructure_imm_config')
        set_ds(conf, 'power', data['Power'], 'W')
        set_ds(conf, 'temperature_seed', tseed, 'K')
        set_ds(conf, 'temperature_source', tsource, 'K')
        set_ds(conf, 'initial_temperature_source', tsource_0, 'K')
        set_ds(conf, 'temperature_difference', dT, 'K')
        set_ds(conf, 'additional_temperature_shift', newdT, 'K')
        set_ds(conf, 'geometry/lenx', lenx, 'lattice units')
        set_ds(conf, 'geometry/leny', leny, 'lattice units')
        set_ds(conf, 'geometry/lenz', lenz, 'lattice units')
        set_ds(conf, 'KMC_lattice_constant', KMC_lattice_constant, 'nm')
        set_ds(conf, 'alat_angstrom', alat, 'Angstrom')
        set_ds(conf, 'simulation_type', b'PVD')
        set_ds(conf, 'substrate_material', b'SiC-3C')
        conf.create_dataset('precursors', data=np.array([b'Si', b'Si2C', b'SiC2']))
        set_ds(conf, 'experiment_identifier', f'PVD-SiC-Run-{sample_id}'.encode())
        set_ds(conf, 'deposition_time', tottime, 's')
        set_ds(conf, 'output_steps', Nout)
        set_ds(conf, 'target_thickness', target_thickness, 'mm')
        set_ds(conf, 'random_seed', randseed)
        set_ds(conf, 'timestamp', str(datetime.datetime.now()))
        set_ds(conf, 'run_directory', runpath.encode())

        # Parametri avanzati
        set_ds(conf, 'simulation_parameters/PtransZig', 0.93)
        set_ds(conf, 'simulation_parameters/ExitStrategy', b'Time')
        set_ds(conf, 'simulation_parameters/SaveCoo', b'False')
        conf.create_dataset('simulation_parameters/Seed_box', data=[48, 0, 0])
        set_ds(conf, 'simulation_parameters/setup_only', b'False')
        set_ds(conf, 'analysis/bin_size', bin_size, 'cm')
        set_ds(conf, 'analysis/surface_roughness', surface_roughness)
        set_ds(conf, 'analysis/Nexclude', Nexclude)

        res = grp('NXmicrostructure_imm_results')
        set_ds(res, 'growth_rate', 0.0 if np.isnan(growth_rate) else growth_rate, 'micron/hour')
        set_ds(res, 'avg_surface_height', 0.0 if np.isnan(avg_surf_height) else avg_surf_height, 'micron')
        set_ds(res, 'growth_rate_method', np.string_(method))
        set_ds(res, 'experimental_growth_rate', data['Exp-Growth-Rate'], 'micron/hour')
        set_ds(res, 'alat_used', alat, 'Angstrom')
        set_ds(res, 'analysis_time', str(datetime.datetime.now()))
        set_ds(res, 'total_time', tottime, 's')
        set_ds(res, 'num_outputs', Nout)
        set_ds(res, 'target_thickness', target_thickness, 'mm')
        set_ds(res, 'vacancies_total', vac_data.get('total', -1))

        for k, v in vac_data.items():
            set_ds(res, f'vacancy_{k}', v)

        set_ds(res, 'xyz_file', np.string_(xyz_txt))
        set_ds(res, 'results_txt', np.string_(results_txt))

        try:
            lines = results_txt.strip().splitlines()
            hdrs = lines[0].split()
            data_mat = np.array([list(map(float, l.split())) for l in lines[1:] if l.strip()])
            for i, h in enumerate(hdrs):
                set_ds(res, f'results_table/{h}', data_mat[:, i])
        except Exception as e:
            print(f"⚠️ Tabella results.txt fallita: {e}")

        try:
            txt = read_file(surf_file)
            tab = np.loadtxt(surf_file)
            if tab.ndim == 1:
                tab = tab.reshape(-1, 2)
            set_ds(res, 'surf_height_txt', np.string_(txt))
            set_ds(res, 'surf_height/time', tab[:, 0], 's')
            set_ds(res, 'surf_height/height', tab[:, 1], 'micron')
        except Exception as e:
            print(f"⚠️ surf_height.txt fallita: {e}")
            set_ds(res, 'surf_height_txt', np.string_("null"))

        log = grp('simulation_log')
        set_ds(log, 'description', b'MulSKIPS simulation log')
        set_ds(log, 'data', np.string_(log_txt))

    print(f"✅ File NeXus scritto con successo: {nexus_file}")
except Exception as e:
    print(f"❌ Errore nella scrittura del NeXus: {e}")
    traceback.print_exc()
# Out:
# ID del campione [default: 153]:
# Lunghezza X [default: 120]:  120
# Lunghezza Y [default: 120]:  120
# Lunghezza Z [default: 480]:  2400
# Seed random [default: 9117116]:
# Delta T aggiuntivo (newdT) [default: 0]:
# Delta T da aggiungere a Tsource [default: 100]:  0
# Metodo di analisi (polyfit o average) [default: polyfit]:
# Bin size (cm) [default: 0.001]:
# Filtro rugosità superficie [default: 0.5]:
# Nexclude (default 3) [default: 3]:
# Compiling MulSKIPS with box size: 120 x 120 x 2400
# Directory changed to: /Users/filipporuberto/miniforge3/envs/mulskips_env/MulSKIPS/mulskips-source
#
# ********************************** Starting MulSKIPS compilation **********************************
# MulSKIPS:	rm ./modules/defdertype.o ./modules/defsystem.o ./modules/definitions.o ./initial/SetAPB.o ./initial/SetInvPC.o ./initial/SetInvPwAPB.o ./initial/SetNCSp.o ./initial/SetNCSpSi.o ./initial/SetAPBSym.o ./initial/SetInvP.o ./initial/SetInvPwOnlyCorSi.o ./initial/SetSiC3C.o ./initial/SetSiCSF.o ./initial/SetSiGex.o ./initial/SetSiC3Cww.o ./initial/SetSiC3Cwwaperture.o ./initial/SetSi.o ./initial/SetSiFINFET.o ./initial/SetCAD.o ./initial/SetT.o ./initial/SetShape.o ./initial/SetAPBSymZimb1.o ./initial/SetInvPOff.o ./initial/SetInvPwOnlySiorC.o ./initial/SetTrenchSi.o ./initial/SetTrench.o ./initial/SetAPBSymZimb.o ./initial/SetInvPSi.o ./initial/SetNC.o ./inpout/FileClose.o ./inpout/GetOutputFileName.o ./inpout/WriteMolMolXYZFile.o ./inpout/FileOpen.o ./inpout/WriteMolMolSource.o ./lattice/FIND_NN.o ./lattice/FIND_SN.o ./mcevent/Add.o ./mcevent/Evaporation.o ./mcevent/PickTreeEvent.o ./mcevent/UpdateTree.o ./mcevent/AllocateArrays.o ./mcevent/Get_Prob.o ./mcevent/random.o ./mcevent/deposition.o ./mcevent/Get_Prob_Ini.o ./mcevent/SetProbability.o ./mcevent/Erase.o ./mcevent/IF_Arm_Choice.o ./mcevent/UpdateCoor.o main.o ./mcevent/absorption.o ./mcevent/desorption.o ./mcevent/InterpProbFromField.o ./mcevent/SetProbabilityFromField.o mulskips.e *.mod
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o modules/defdertype.o modules/defdertype.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o modules/defsystem.o modules/defsystem.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o modules/definitions.o modules/definitions.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetAPB.o initial/SetAPB.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvPC.o initial/SetInvPC.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvPwAPB.o initial/SetInvPwAPB.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetNCSp.o initial/SetNCSp.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetNCSpSi.o initial/SetNCSpSi.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetAPBSym.o initial/SetAPBSym.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvP.o initial/SetInvP.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvPwOnlyCorSi.o initial/SetInvPwOnlyCorSi.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSiC3C.o initial/SetSiC3C.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSiCSF.o initial/SetSiCSF.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSiGex.o initial/SetSiGex.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSiC3Cww.o initial/SetSiC3Cww.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSiC3Cwwaperture.o initial/SetSiC3Cwwaperture.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSi.o initial/SetSi.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetSiFINFET.o initial/SetSiFINFET.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetCAD.o initial/SetCAD.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetT.o initial/SetT.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetShape.o initial/SetShape.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetAPBSymZimb1.o initial/SetAPBSymZimb1.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvPOff.o initial/SetInvPOff.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvPwOnlySiorC.o initial/SetInvPwOnlySiorC.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetTrenchSi.o initial/SetTrenchSi.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetTrench.o initial/SetTrench.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetAPBSymZimb.o initial/SetAPBSymZimb.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetInvPSi.o initial/SetInvPSi.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o initial/SetNC.o initial/SetNC.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o inpout/FileClose.o inpout/FileClose.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o inpout/GetOutputFileName.o inpout/GetOutputFileName.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o inpout/WriteMolMolXYZFile.o inpout/WriteMolMolXYZFile.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o inpout/FileOpen.o inpout/FileOpen.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o inpout/WriteMolMolSource.o inpout/WriteMolMolSource.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o lattice/FIND_NN.o lattice/FIND_NN.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o lattice/FIND_SN.o lattice/FIND_SN.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/Add.o mcevent/Add.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/Evaporation.o mcevent/Evaporation.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/PickTreeEvent.o mcevent/PickTreeEvent.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/UpdateTree.o mcevent/UpdateTree.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/AllocateArrays.o mcevent/AllocateArrays.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/Get_Prob.o mcevent/Get_Prob.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/random.o mcevent/random.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/deposition.o mcevent/deposition.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/Get_Prob_Ini.o mcevent/Get_Prob_Ini.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/SetProbability.o mcevent/SetProbability.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/Erase.o mcevent/Erase.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/IF_Arm_Choice.o mcevent/IF_Arm_Choice.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/UpdateCoor.o mcevent/UpdateCoor.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o main.o main.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/absorption.o mcevent/absorption.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/desorption.o mcevent/desorption.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/InterpProbFromField.o mcevent/InterpProbFromField.f
# MulSKIPS:	/usr/local/bin/gfortran-14 -g  -c -o mcevent/SetProbabilityFromField.o mcevent/SetProbabilityFromField.f
# MulSKIPS:	single file...
# MulSKIPS:	Now compiling...
# MulSKIPS:	/usr/local/bin/gfortran-14  -g ./modules/defdertype.o ./modules/defsystem.o ./modules/definitions.o ./initial/SetAPB.o ./initial/SetInvPC.o ./initial/SetInvPwAPB.o ./initial/SetNCSp.o ./initial/SetNCSpSi.o ./initial/SetAPBSym.o ./initial/SetInvP.o ./initial/SetInvPwOnlyCorSi.o ./initial/SetSiC3C.o ./initial/SetSiCSF.o ./initial/SetSiGex.o ./initial/SetSiC3Cww.o ./initial/SetSiC3Cwwaperture.o ./initial/SetSi.o ./initial/SetSiFINFET.o ./initial/SetCAD.o ./initial/SetT.o ./initial/SetShape.o ./initial/SetAPBSymZimb1.o ./initial/SetInvPOff.o ./initial/SetInvPwOnlySiorC.o ./initial/SetTrenchSi.o ./initial/SetTrench.o ./initial/SetAPBSymZimb.o ./initial/SetInvPSi.o ./initial/SetNC.o ./inpout/FileClose.o ./inpout/GetOutputFileName.o ./inpout/WriteMolMolXYZFile.o ./inpout/FileOpen.o ./inpout/WriteMolMolSource.o ./lattice/FIND_NN.o ./lattice/FIND_SN.o ./mcevent/Add.o ./mcevent/Evaporation.o ./mcevent/PickTreeEvent.o ./mcevent/UpdateTree.o ./mcevent/AllocateArrays.o ./mcevent/Get_Prob.o ./mcevent/random.o ./mcevent/deposition.o ./mcevent/Get_Prob_Ini.o ./mcevent/SetProbability.o ./mcevent/Erase.o ./mcevent/IF_Arm_Choice.o ./mcevent/UpdateCoor.o main.o ./mcevent/absorption.o ./mcevent/desorption.o ./mcevent/InterpProbFromField.o ./mcevent/SetProbabilityFromField.o -lquadmath -lgfortran -lgcc_s.1 -o ./mulskips.e -L/usr/local/Cellar/openblas/0.3.29/lib -lopenblas -lpthread -Wl,-rpath,/usr/local/Cellar/gcc/14.2.0_1/lib/gcc/14
# MulSKIPS:	#/usr/local/bin/gfortran-14  -g ./modules/defdertype.o ./modules/defsystem.o ./modules/definitions.o ./initial/SetAPB.o ./initial/SetInvPC.o ./initial/SetInvPwAPB.o ./initial/SetNCSp.o ./initial/SetNCSpSi.o ./initial/SetAPBSym.o ./initial/SetInvP.o ./initial/SetInvPwOnlyCorSi.o ./initial/SetSiC3C.o ./initial/SetSiCSF.o ./initial/SetSiGex.o ./initial/SetSiC3Cww.o ./initial/SetSiC3Cwwaperture.o ./initial/SetSi.o ./initial/SetSiFINFET.o ./initial/SetCAD.o ./initial/SetT.o ./initial/SetShape.o ./initial/SetAPBSymZimb1.o ./initial/SetInvPOff.o ./initial/SetInvPwOnlySiorC.o ./initial/SetTrenchSi.o ./initial/SetTrench.o ./initial/SetAPBSymZimb.o ./initial/SetInvPSi.o ./initial/SetNC.o ./inpout/FileClose.o ./inpout/GetOutputFileName.o ./inpout/WriteMolMolXYZFile.o ./inpout/FileOpen.o ./inpout/WriteMolMolSource.o ./lattice/FIND_NN.o ./lattice/FIND_SN.o ./mcevent/Add.o ./mcevent/Evaporation.o ./mcevent/PickTreeEvent.o ./mcevent/UpdateTree.o ./mcevent/AllocateArrays.o ./mcevent/Get_Prob.o ./mcevent/random.o ./mcevent/deposition.o ./mcevent/Get_Prob_Ini.o ./mcevent/SetProbability.o ./mcevent/Erase.o ./mcevent/IF_Arm_Choice.o ./mcevent/UpdateCoor.o main.o ./mcevent/absorption.o ./mcevent/desorption.o ./mcevent/InterpProbFromField.o ./mcevent/SetProbabilityFromField.o -o ./mulskips.e -L/opt/homebrew/opt/openblas/lib -lopenblas -lpthread
# MulSKIPS:	Compilation terminated
# ld: warning: ignoring duplicate libraries: '-lgfortran', '-lquadmath'
# ********************************** Finished MulSKIPS compilation **********************************
#
# Directory changed to: /Users/filipporuberto/miniforge3/envs/mulskips_env/MulSKIPS
# *** Initializing PVD process for SiC-3C substrate with precursors ['Si', 'Si2C', 'SiC2']
# precursor_masses 	--> Precursor Masses [kg/mol]: {'Si': 0.028085000000000002, 'Si2C': 0.068181, 'SiC2': 0.052107}
# mass 			--> Substrate Mass [Kg/mol]: 0.040096
# rho 			--> Substrate Density [Kg/m^3]: 3210
# rho_surf 		--> Substrate Surface density [Kg/m^2]: 1.400038787156981e-06
# calibration_type 	--> Calibration of fluxes taken from:  avrov
# Tsource 	--> Temperature at source:  2353.35
# Tseed_center 	--> Temperature at seed center: 2345.39
# KMC_sf 			--> Substrate KMC super-lattice constant [angstrom]: 0.36333333333333334
# listcry 		--> Crystalline species in the substrate: ['Si', 'C']
# listcryZ 		--> Atomic number of Crystalline species in the substrate: [14, 6]
# calibration_params 	--> Calibration parameters:
#      fact_D_Si 	--> [1.10546, 0.276365, 44.2184]
#      fact_D_C 	--> [200.0, 2.5, 400.0]
#      scalef 	--> 0.43
#
# ********************************** Generating MulSKIPs input file (start.dat) **********************************
# *********** Input arguments:
# Executable directory:  /Users/filipporuberto/miniforge3/envs/mulskips_env/MulSKIPS/mulskips-source
# Simulation directory:  parser/data-0.0-0-9117116
# Type of simulation:  F
# Error: parser/data-0.0-0-9117116 : No such file or directory
# Successfully created the directory parser/data-0.0-0-9117116
# Directory changed to: parser/data-0.0-0-9117116
# Mulskips class:  <pymulskips.process.PVD object at 0x12a699eb0>
# PtransZig:  0.93
# ExitStrategy:  Time
# TotTime:  0.984418118466899 sec
# OutTime:  0.010937979094076655 sec
# Size of the system:  [48, 0, 0]
# RunType:  R
# IDUM:  9117116
# SaveFinalState:  False
# SaveCoo:  False
# Only generate start.dat and do not run:  False
#
# Evaporation energetics:
#  [[[ 0.        6.83      7.04      7.77    ]
#   [ 6.72      6.784     7.186     0.      ]
#   [ 6.77224   6.9812    0.        0.      ]
#   [ 6.814032  0.        0.        0.      ]]
#
#  [[ 0.        7.76      8.21056   8.571008]
#   [ 9.1       9.566    10.0128    0.      ]
#   [11.43     11.504     0.        0.      ]
#   [11.8       0.        0.        0.      ]]]
# Evaporation probabilities:
#  [[[9.23669339e+18 1.94625810e+04 6.88576284e+03 1.85920281e+02]
#   [3.35404301e+04 2.44368551e+04 3.34369767e+03 9.23669339e+18]
#   [2.59009219e+04 9.21089019e+03 9.23669339e+18 9.23669339e+18]
#   [2.10626252e+04 9.23669339e+18 9.23669339e+18 9.23669339e+18]]
#
#  [[7.90748043e+27 1.67238546e+11 1.79958456e+10 3.02441203e+09]
#   [2.20770993e+08 2.20090038e+07 2.41276906e+06 7.90748043e+27]
#   [2.17387158e+03 1.50737932e+03 7.90748043e+27 7.90748043e+27]
#   [3.48479496e+02 7.90748043e+27 7.90748043e+27 7.90748043e+27]]]
#
# Deposition energetics:
#  [[ 7.04  7.04  7.04]
#  [11.43 11.43 11.43]]
# Deposition probabilities:
#  [[  3385.54122975    846.38530744 135421.64918994]
#  [196184.20224607   2452.30252808 392368.40449213]]
# Number of evaporation probabilities:  18
# DONE writing start.dat
# DONE MulSKIPs setup. ETA: 0.0021419525146484375 sec
# The executable directory is /Users/filipporuberto/miniforge3/envs/mulskips_env/MulSKIPS/mulskips-source
#
# ********************************** Starting MulSKIPs **********************************
# KMC:	 KMC box size:          120         120        2400
# KMC:	            ***** Simulating PVD or LA *****
# KMC:	 Crystal species (NCrystal=           2 ) --> Z:          14           6
# KMC:	 ECCOMIIIIII
# KMC:	 KMC Super-Lattice parameter (ang):   0.36333333333333301
# KMC:	 Exit strategy: Time
# KMC:	 Total simulation time in seconds:   0.98441811846689897
# KMC:	 Output frequency in seconds:    1.0937979094077000E-002
# KMC:	 IDUM     9117116
# KMC:	 SaveFinalState flag is not "T": checkpoint file will  not be written.
# KMC:	 SaveCoo flag is not "T": Coor file not stored
# KMC:	 maxElines          18
# KMC:	 numParticelle=      500000 Levels =          20 , SizeTree =     1048575
# KMC:	 Atoms,Voids,AdAtoms        3000           0         400
# KMC:	 I00000000
# KMC:	           0
# KMC:	 NumAtWrong:            0
# KMC:	 SUM(CountCrystal)         713
# KMC:	 CountCrystal         408         305           0
# KMC:	 CountCrystalOld           0           0           0
# KMC:	 diff   408.00000000000000        305.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0
00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.49213286713286714       0.50786713286713292        0.0000000000000000
# KMC:	 I00000072
# KMC:	           0
# KMC:	 NumAtWrong:            9
# KMC:	 Iter, Time, Site             46027496  0.78753452053380824               84         108        1140
# KMC:	 NatNvoidNad       75387           3         607
# KMC:	 SUM(CountCrystal)       73587
# KMC:	 CountCrystal       36886       36701           0
# KMC:	 CountCrystalOld       36334       36163           0
# KMC:	 diff   552.00000000000000        538.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50642201834862388       0.49357798165137617        0.0000000000000000
# KMC:	 I00000073
# KMC:	           0
# KMC:	 NumAtWrong:           21
# KMC:	 Iter, Time, Site             46670196  0.79847249516869523              117         117        1155
# KMC:	 NatNvoidNad       76476           3         609
# KMC:	 SUM(CountCrystal)       74695
# KMC:	 CountCrystal       37443       37252           0
# KMC:	 CountCrystalOld       36886       36701           0
# KMC:	 diff   557.00000000000000        551.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50270758122743686       0.49729241877256319        0.0000000000000000
# KMC:	 I00000074
# KMC:	           0
# KMC:	 NumAtWrong:           13
# KMC:	 Iter, Time, Site             47303580  0.80941048136623728               63          51        1167
# KMC:	 NatNvoidNad       77575           3         629
# KMC:	 SUM(CountCrystal)       75657
# KMC:	 CountCrystal       37917       37740           0
# KMC:	 CountCrystalOld       37443       37252           0
# KMC:	 diff   474.00000000000000        488.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.49272349272349275       0.50727650727650730        0.0000000000000000
# KMC:	 I00000075
# KMC:	           0
# KMC:	 NumAtWrong:           24
# KMC:	 Iter, Time, Site             47931660  0.82034844407073892                3          87        1179
# KMC:	 NatNvoidNad       78548           3         605
# KMC:	 SUM(CountCrystal)       76563
# KMC:	 CountCrystal       38377       38186           0
# KMC:	 CountCrystalOld       37917       37740           0
# KMC:	 diff   460.00000000000000        446.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50772626931567333       0.49227373068432673        0.0000000000000000
# KMC:	 I00000076
# KMC:	           0
# KMC:	 NumAtWrong:           26
# KMC:	 Iter, Time, Site             48577380  0.83128643037991079               30          42        1200
# KMC:	 NatNvoidNad       79453           4         593
# KMC:	 SUM(CountCrystal)       77444
# KMC:	 CountCrystal       38818       38626           0
# KMC:	 CountCrystalOld       38377       38186           0
# KMC:	 diff   441.00000000000000        440.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50056753688989786       0.49943246311010214        0.0000000000000000
# KMC:	 I00000077
# KMC:	           0
# KMC:	 NumAtWrong:           24
# KMC:	 Iter, Time, Site             49201371  0.84222440195472326               57          21        1215
# KMC:	 NatNvoidNad       80336           3         610
# KMC:	 SUM(CountCrystal)       78500
# KMC:	 CountCrystal       39351       39149           0
# KMC:	 CountCrystalOld       38818       38626           0
# KMC:	 diff   533.00000000000000        523.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50473484848484851       0.49526515151515149        0.0000000000000000
# KMC:	 I00000078
# KMC:	           0
# KMC:	 NumAtWrong:           24
# KMC:	 Iter, Time, Site             49867903  0.85316238658431998               45          51        1221
# KMC:	 NatNvoidNad       81374           3         638
# KMC:	 SUM(CountCrystal)       79599
# KMC:	 CountCrystal       39901       39698           0
# KMC:	 CountCrystalOld       39351       39149           0
# KMC:	 diff   550.00000000000000        549.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.
00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50466200466200462       0.49533799533799533        0.0000000000000000
# KMC:	 I00000086
# KMC:	           0
# KMC:	 NumAtWrong:           28
# KMC:	 Iter, Time, Site             54993769  0.94066621145722995               21          93        1347
# KMC:	 NatNvoidNad       89108           3         625
# KMC:	 SUM(CountCrystal)       87259
# KMC:	 CountCrystal       43732       43527           0
# KMC:	 CountCrystalOld       43220       43010           0
# KMC:	 diff   512.00000000000000        517.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.49757045675413020       0.50242954324586975        0.0000000000000000
# KMC:	 I00000087
# KMC:	           0
# KMC:	 NumAtWrong:           25
# KMC:	 Iter, Time, Site             55633394  0.95160420781576127               63          27        1359
# KMC:	 NatNvoidNad       90144           3         614
# KMC:	 SUM(CountCrystal)       88367
# KMC:	 CountCrystal       44282       44085           0
# KMC:	 CountCrystalOld       43732       43527           0
# KMC:	 diff   550.00000000000000        558.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.49638989169675091       0.50361010830324915        0.0000000000000000
# KMC:	 I00000088
# KMC:	           0
# KMC:	 NumAtWrong:           26
# KMC:	 Iter, Time, Site             56292060  0.96254218335482333                6          48        1374
# KMC:	 NatNvoidNad       91258           3         614
# KMC:	 SUM(CountCrystal)       89417
# KMC:	 CountCrystal       44812       44605           0
# KMC:	 CountCrystalOld       44282       44085           0
# KMC:	 diff   530.00000000000000        520.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.50476190476190474       0.49523809523809526        0.0000000000000000
# KMC:	 I00000089
# KMC:	           0
# KMC:	 NumAtWrong:           21
# KMC:	 Iter, Time, Site             56941026  0.97348016152449290              105           3        1389
# KMC:	 NatNvoidNad       92297           3         625
# KMC:	 SUM(CountCrystal)       90418
# KMC:	 CountCrystal       45309       45109           0
# KMC:	 CountCrystalOld       44812       44605           0
# KMC:	 diff   497.00000000000000        504.00000000000000        0.0000000000000000
# KMC:	 xGesolid  0.49650349650349651       0.50349650349650354        0.0000000000000000
# KMC:	 I00000090
# KMC:	           0
# KMC:	 NumAtWrong:           25
# KMC:	 Iter, Time, Site             57578911  0.98441812684952434               54         114        1404
# KMC:	 NatNvoidNad       93317           3         594
# KMC:	 SUM(CountCrystal)       90419
# KMC:	 CountCrystal       45309       45110           0
# KMC:	 CountCrystalOld       45309       45109           0
# KMC:	 diff   0.0000000000000000        1.0000000000000000        0.0000000000000000
# KMC:	 xGesolid   0.0000000000000000        1.0000000000000000        0.0000000000000000
# KMC:	 I00000090
# KMC:	           0
# KMC:	 NumAtWrong:           25
# ********************************** Finished MulSKIPs **********************************
#
# DONE MulSKIPs run. ETA: 923.636069059372 sec
# Directory changed to: /Users/filipporuberto/miniforge3/envs/mulskips_env/MulSKIPS
# ⚠️ Growth rate fallita: analyze_growth_rate() got an unexpected keyword argument 'return_surf_height'
# ⚠️ File mancante: parser/data-0.0-0-9117116/9117116_v.xyz
# ⚠️ File mancante: parser/data-0.0-0-9117116/results.txt
# ⚠️ Tabella results.txt fallita: too many indices for array: array is 1-dimensional, but 2 were indexed
# ⚠️ File mancante: parser/data-0.0-0-9117116/surf_height.txt
# ⚠️ surf_height.txt fallita: parser/data-0.0-0-9117116/surf_height.txt not found.
# ✅ File NeXus scritto con successo: SiC_sample_153.nxs
